# %%
import numpy as np
import pandas as pd

# %%
perf_data=pd.read_csv("Desktop/Datasets/StudentsPerformance.csv")

# %%
perf_data.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A          associate's degree  free/reduced
# 1    male        group A                some college      standard
# 2  female        group A             master's degree      standard
# 3    male        group A             master's degree  free/reduced
# 4  female        group A          associate's degree      standard
# 5    male        group A            some high school  free/reduced
# 6    male        group A          associate's degree  free/reduced
# 7  female        group A          associate's degree  free/reduced
# 8    male        group A           bachelor's degree      standard
# 9    male        group A                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none        47.0           57.0           44.0
# 1               completed        78.0           72.0           70.0
# ...

# %%
Gender_filter=perf_data["parental level of education"].isin(["some college","master's degree"])
Gender_filter.head(10)
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9     True
# Name: parental level of education, dtype: bool

# %%
perf_data[Gender_filter].head(10)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 1     male        group A                some college      standard
# 2   female        group A             master's degree      standard
# 3     male        group A             master's degree  free/reduced
# 9     male        group A                some college  free/reduced
# 10  female        group A                some college      standard
# 20    male        group A                some college  free/reduced
# 21    male        group A                some college      standard
# 22    male        group A                some college  free/reduced
# 30    male        group A                some college      standard
# 31  female        group A                some college  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 1                completed        78.0           72.0           70.0
# 2                     none         NaN            NaN            NaN
# ...

# %%
perf_data[~Gender_filter].head(10)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0     male        group A          associate's degree  free/reduced
# 4   female        group A          associate's degree      standard
# 5     male        group A            some high school  free/reduced
# 6     male        group A          associate's degree  free/reduced
# 7   female        group A          associate's degree  free/reduced
# 8     male        group A           bachelor's degree      standard
# 11    male        group A          associate's degree      standard
# 12  female        group A           bachelor's degree      standard
# 13    male        group A                 high school      standard
# 14    male        group A            some high school      standard
#
#    test preparation course  math score  reading score  writing score
# 0                     none        47.0           57.0           44.0
# 4                completed        55.0           65.0           62.0
# ...

# %%
Complex_condition=perf_data["gender"].isin(["female"])&(perf_data["reading score"]==65.0)&(perf_data["writing score"]==65.0)
Complex_condition.head(10)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
perf_data[Complex_condition].head(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 270  female        group B          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 270                    none        54.0           65.0           65.0

# %%
perf_data.filter(items=["gender","lunch","race ethnicity","math score","test preparation","writing score","reading score"]).head(10)
# Out:
#    gender         lunch  math score  writing score  reading score
# 0    male  free/reduced        47.0           44.0           57.0
# 1    male      standard        78.0           70.0           72.0
# 2  female      standard         NaN            NaN            NaN
# 3    male  free/reduced        73.0           72.0           74.0
# 4  female      standard        55.0           62.0           65.0
# 5    male  free/reduced        39.0           34.0           39.0
# 6    male  free/reduced        62.0           55.0           61.0
# 7  female  free/reduced        41.0           48.0           51.0
# 8    male      standard        80.0           81.0           78.0
# 9    male  free/reduced        50.0           54.0           47.0

# %%
Course_filter=perf_data["test preparation course"].isin(["completed"])
Course_filter.head(10)
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8     True
# 9     True
# Name: test preparation course, dtype: bool

# %%
perf_data[Course_filter].head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-27ef5534143b> in <module>
# ----> 1 perf_data[Course_filter].head(10)
#
# NameError: name 'Course_filter' is not defined

# %%
perf_data[Course_female_filter].head(10)
# Out:
#     gender         lunch race_ethnicity  math_score test_preparation  \
# 4   female      standard        group A        55.0        completed
# 32  female      standard        group A        59.0        completed
# 39  female  free/reduced        group A        77.0        completed
# 46  female      standard        group A        92.0        completed
# 57  female      standard        group A        68.0        completed
# 58  female      standard        group A        65.0        completed
# 66  female      standard        group A        72.0        completed
# 71  female      standard        group A        85.0        completed
# 74  female      standard        group A        75.0        completed
# 77  female  free/reduced        group A        34.0        completed
#
#     writing_score  reading_score parental_level_of_education
# 4            62.0           65.0          associate's degree
# 32           80.0           85.0            some high school
# ...

# %%
perf_data[Course_filter& Complex_condition].head(10)
# Out:
#      gender         lunch race_ethnicity  math_score test_preparation  \
# 58   female      standard        group A        65.0        completed
# 66   female      standard        group A        72.0        completed
# 71   female      standard        group A        85.0        completed
# 83   female  free/reduced        group A        53.0        completed
# 85   female      standard        group A        78.0        completed
# 123  female      standard        group B        61.0        completed
# 126  female  free/reduced        group B        58.0        completed
# 128  female  free/reduced        group B        46.0        completed
# 141  female      standard        group B        52.0        completed
# 146  female      standard        group B        60.0        completed
#
#      writing_score  reading_score parental_level_of_education
# 58            74.0           70.0          associate's degree
# 66            82.0           79.0                some college
# ...

# %%
def numb():
        _inp=input("Enter a number\n")
        if _inp.isdigit() is True:
            return _inp
        else:
            _inp.isalpha() is True
        return numb()
      
numlist=[]
while (True):
    _digitinp=numb()
    Value=float(_digitinp)
    numlist.append(Value)
    _totallist=sum(numlist)
    print(numlist,"Average:",_totallist/len(numlist))
# Out:
# Enter a number
# 5
# [5.0] Average: 5.0
# Enter a number
# 6
# [5.0, 6.0] Average: 5.5
# Enter a number
#
# Enter a number
# 7
# [5.0, 6.0, 7.0] Average: 6.0
# Enter a number
# 7
# [5.0, 6.0, 7.0, 7.0] Average: 6.25
# Enter a number
# y
# Enter a number
# 4
# [5.0, 6.0, 7.0, 7.0, 4.0] Average: 5.8
# Enter a number
# s
# Enter a number
# 6
# [5.0, 6.0, 7.0, 7.0, 4.0, 6.0] Average: 5.833333333333333

# %%
perf_data.filter(regex="score",axis=1).head(10)
# Out:
#    math score  reading score  writing score
# 0        47.0           57.0           44.0
# 1        78.0           72.0           70.0
# 2         NaN            NaN            NaN
# 3        73.0           74.0           72.0
# 4        55.0           65.0           62.0
# 5        39.0           39.0           34.0
# 6        62.0           61.0           55.0
# 7        41.0           51.0           48.0
# 8        80.0           78.0           81.0
# 9        50.0           47.0           54.0

# %%
perf_data.filter(like="14",axis=0).head(10)
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 14     male        group A            some high school  standard
# 114  female        group B            some high school  standard
# 140    male        group B          associate's degree  standard
# 141  female        group B          associate's degree  standard
# 142  female        group B           bachelor's degree  standard
# 143    male        group B                some college  standard
# 144  female        group B                 high school  standard
# 145  female        group B                 high school  standard
# 146  female        group B            some high school  standard
# 147  female        group B                some college  standard
#
#     test preparation course  math score  reading score  writing score
# 14                completed        62.0           67.0           69.0
# 114                    none        70.0           64.0           72.0
# ...

# %%
groupB=perf_data["race/ethnicity"]=="group B"
perf_data[groupB]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A          associate's degree  free/reduced
# 1      male        group A                some college      standard
# 2    female        group A             master's degree      standard
# 3      male        group A             master's degree  free/reduced
# 4    female        group A          associate's degree      standard
# 5      male        group A            some high school  free/reduced
# 6      male        group A          associate's degree  free/reduced
# 7    female        group A          associate's degree  free/reduced
# 8      male        group A           bachelor's degree      standard
# 9      male        group A                some college  free/reduced
# 10   female        group A                some college      standard
# 11     male        group A          associate's degree      standard
# 12   female        group A           bachelor's degree      standard
# ...
