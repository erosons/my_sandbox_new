# %%
import pandas as pd

# %%
import csv

# %%
xfile=open("Desktop/Data_Analysis/")

# %%
for Series in xfile:
    Series=List((Series))

# %%
Series
# Out:
# '1,2,3,4,5,6,7'

# %%
mylist=pd.Series(Series)

# %%
mylist
# Out:
# 0    1,2,3,4,5,6,7
# dtype: object

# %%
file_1=pd.read_csv("Desktop/Data_Analysis/Datasets/ZoomCars.csv")

# %%
file_1.isna().sum()
# Out:
# id                     0
# url                    0
# priority               0
# page                   0
# fetched                0
# price_currency         1
# price_value            1
# ad_id                  0
# posted_weekday         0
# posted_time            0
# posted_month           0
# posted_day             0
# posted_year            0
# delivery_offered     789
# price_negotiable       0
# condition              0
# year                   0
# make                   0
# model                172
# current_location       0
# import_duty_paid       0
# mileage             3028
# transmission           2
# four_wheel_drive       0
# location               0
# description            0
# dtype: int64

# %%
file_1.shape
# Out:
# (3844, 26)

# %%
file_1=file_1.dropna()

# %%
file_1.shape
# Out:
# (693, 26)

# %%
file_1
# Out:
#         id                                                url priority  page  \
# 1        2  https://www.zoomtanzania.com/sedans/2005-bmw-1...     gold     1
# 10      11  https://www.zoomtanzania.com/hatchbacks/2004-t...     gold     2
# 11      12  https://www.zoomtanzania.com/hatchbacks/2005-t...     gold     2
# 20      21  https://www.zoomtanzania.com/minis/2004-toyota...     gold     3
# 21      22  https://www.zoomtanzania.com/sedans/2009-toyot...     gold     3
# 22      23  https://www.zoomtanzania.com/4x4s-suvs/2012-to...   silver     3
# 24      25  https://www.zoomtanzania.com/station-wagons/20...   silver     3
# 27      28  https://www.zoomtanzania.com/hatchbacks/2004-t...   silver     3
# 28      29  https://www.zoomtanzania.com/hatchbacks/2003-t...   silver     3
# 29      30  https://www.zoomtanzania.com/hatchbacks/2008-t...   silver     3
# 34      36  https://www.zoomtanzania.com/4x4s-suvs/2005-su...   silver     4
# ...

# %%
file_1.isna().sum()
# Out:
# id                  0
# url                 0
# priority            0
# page                0
# fetched             0
# price_currency      0
# price_value         0
# ad_id               0
# posted_weekday      0
# posted_time         0
# posted_month        0
# posted_day          0
# posted_year         0
# delivery_offered    0
# price_negotiable    0
# condition           0
# year                0
# make                0
# model               0
# current_location    0
# import_duty_paid    0
# mileage             0
# transmission        0
# four_wheel_drive    0
# location            0
# description         0
# dtype: int64

# %%
file_1=file_1.drop(labels=["id","url","page","fetched","price_currency","ad_id","current_location","import_duty_paid","location","description"],axis=1)

# %%
file_1
# Out:
#      posted_weekday posted_month  posted_day  posted_year delivery_offered  \
# 1            Friday     November           2         2018               No
# 10           Friday     November           2         2018               No
# 11           Friday     November           2         2018              Yes
# 20           Friday     November           2         2018               No
# 21           Friday     November           2         2018               No
# 22           Friday     November           2         2018              Yes
# 24           Friday     November           2         2018               No
# 27           Friday     November           2         2018               No
# 28           Friday     November           2         2018              Yes
# 29           Friday     November           2         2018              Yes
# 34           Monday    September          17         2018               No
# ...
