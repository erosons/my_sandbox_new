# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas_datareader.data as data
from datetime import datetime
start = datetime(2001, 1, 1)
end=datetime.today()
findata=data.DataReader('BP', 'yahoo', start, end)
findata
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2001-01-02  49.437500  48.562500  49.062500  48.625000   2431200.0  19.305607
# 2001-01-03  49.437500  47.562500  49.250000  47.875000   3861900.0  19.007835
# 2001-01-04  48.125000  47.187500  47.812500  47.875000   3025400.0  19.007835
# 2001-01-05  48.812500  48.375000  48.375000  48.687500   3614100.0  19.330423
# 2001-01-08  49.312500  48.562500  49.000000  48.625000   1874300.0  19.305607
# ...               ...        ...        ...        ...         ...        ...
# 2020-06-01  23.910000  23.010000  23.150000  23.840000  10749700.0  23.840000
# 2020-06-02  24.990000  24.610001  24.719999  24.950001  13095800.0  24.950001
# 2020-06-03  26.000000  25.549999  25.670000  25.900000  12323500.0  25.900000
# 2020-06-04  25.840000  25.250000  25.629999  25.690001   8651800.0  25.690001
# 2020-06-05  27.940001  27.250000  27.250000  27.709999  18375800.0  27.709999
#
# [4887 rows x 6 columns]

# %%
# single level filter or if logic
findata["Up"]=np.where(findata["Open"]-findata["Close"]>0,"up","down")
findata["Up"]
# Out:
# Date
# 2001-01-02      up
# 2001-01-03      up
# 2001-01-04    down
# 2001-01-05    down
# 2001-01-08      up
#               ...
# 2020-06-01    down
# 2020-06-02    down
# 2020-06-03    down
# 2020-06-04    down
# 2020-06-05    down
# Name: Up, Length: 4887, dtype: object

# %%
#  plotting a bar chart
findata["Adj Close"].head(20).plot(kind="bar")
plt.show()

# %%
#  plot the time series analysis
findata["Adj Close"].plot(kind="line",figsize=(13,7))

plt.ylabel("BP Adj Close Price")
plt.xlabel("Year")

plt.show()
