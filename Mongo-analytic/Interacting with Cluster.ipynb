# %%
import import_ipynb
import pymongo 
from pymongo import MongoClient
import pandas as pd
from Access import access

# Connect to MangoDB Cluster
client = MongoClient("mongodb+srv://username:paswd@clustertest.urljf.mongodb.net/<dbname>?retryWrites=true&w=majority")

# Connect to On premise
# Out:
# importing Jupyter notebook from Access.ipynb

# %%
db=client["DBPROD"]
collection=db["Customerprofile"]
list(collection.find({"CES_LDC_ID":{"$gt":74,"$lt":85}}))
# Out:
# [{'_id': ObjectId('5fc7d89f11a33a020142f4c2'),
#   'index': 0,
#   'CES_LDC_ID': 75.0,
#   'CES_BILL_ACCT_NUM': 11000000001,
#   'CES_CUST_NUM': 74.0,
#   'UTIL_ACCT_NUM': 1624854165,
#   'UTIL_ACCT_ACCT_CREATION_DT': '2019-07-01',
#   'UTIL_ACCT_START_DT': '2010-09-09',
#   'UTIL_ACCT_END_DT': nan,
#   'UTIL_METER_NUM': '12802816',
#   'UTILITY': 'SoCal',
#   'VENDOR_ID': 139.0,
#   'SEGMENT': 'LCOM',
#   'CUST_COMPANY_NAME': 'CENTURY FAST FOODS INC (SOCAL)',
#   'CUST_FIRSTNAME': nan,
#   'CUST_LASTNAME': 'CENTURY FAST FOODS INC (SOCAL)',
#   'SVC_ADDR_1': '859 N MOUNTAIN AVE',
#   'SVC_ADDR_2': nan,
#   'SVC_CITY': 'ONTARIO',
#   'SVC_STATE': 'CA',
#   'SVC_POSTAL_CODE': 91762.0,
#   'MAIL_ADDR_1': 'ATTN: A/P',
#   'MAIL_ADDR_2': '10350 SANTA MONICA BLVD SUITE 260',
#   'MAIL_CITY': 'LOS ANGELES',
#   'MAIL_STATE': 'CA',
#   'MAIL_POSTAL_CODE': 90025,
#   'USAGE_SUM': 28389.0,
#   'USAGE_CNT': 81,
#   'USAGE_MTH_EST': 350.0,
#   'USAGE_YRLY_EST': 4205.0,
# ...
